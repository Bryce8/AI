# %%
import pandas as pd

import seaborn as sns
df =  pd.read_csv('spotify_songs.csv', encoding = "ISO-8859-1")

df["track_popularity"] = pd.to_numeric(df["track_popularity"], errors="coerce")
sns.histplot(data=df, x="track_popularity", bins=100)
# Out:
# <AxesSubplot:xlabel='track_popularity', ylabel='Count'>

# %% [markdown]
# # the mode of the songs with the track popularity count is
